# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
a = 5
print(a)
# Out:
# 5

# %%
print(a*3)
# Out:
# 15

# %%
a = [1,2,3]
b = [10,100,1000]
print(a+b)
# Out:
# [1, 2, 3, 10, 100, 1000]

# %%
print(a*b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-47507e997195> in <module>()
# ----> 1 print(a*b)
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
print(a*3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([10,100,1000])
print(a)
# Out:
# [1 2 3]

# %%
list(a)
# Out:
# [1, 2, 3]

# %%
print(a+b)
# Out:
# [  11  102 1003]

# %%
print(a*b)
# Out:
# [  10  200 3000]

# %%
a = 3
print(type(a))
# Out:
# <class 'int'>

# %%
b = 4.5
print(type(b))
# Out:
# <class 'float'>

# %%
print(a*b, type(a*b))
# Out:
# 13.5 <class 'float'>

# %% [markdown]
# Blocks are defined by indentation. Looks nice and no needs for end :-)

# %%
for i in [1,2,3]: 
    print(i)

# %%
for i in range(10):
    if i > 5:
        print(i)
# Out:
# 6
# 7
# 8
# 9

# %%
for i in range(10):
    if i > 5:
        print(i)
    else:
        print('i lower than five')
# Out:
# i lower than five
# i lower than five
# i lower than five
# i lower than five
# i lower than five
# i lower than five
# 6
# 7
# 8
# 9

# %% [markdown]
# if...elif...else while... for...

# %%
A = [i**2 for i in range(4)]

# %%
print(A)
# Out:
# [0, 1, 4, 9]

# %%
for s in 'abcdefrtyfgwe':
    print(s)
# Out:
# a
# b
# c
# d
# e
# f
# r
# t
# y
# f
# g
# w
# e

# %%
for s in ['a', 'b', 'c']:
    print(s)
# Out:
# a
# b
# c

# %%
def func1(x):
    print(x**3)
    # in the function
    # End of func1
# Out of the function
func1(100)
# Out:
# 1000000

# %%
def func2(x):
    return(x**3)
print(func2(3))
# Out:
# 27

# %%
def func3(x, y, z, a=0, b=1):
    return a + b * np.sqrt(x**2 + y**2 + z**2)
D = func3(3, 4, 5)
print('my result is: {0:5.3f}, A is {1}'.format(D, A))
# Out:
# my result is: 7.071, A is [0, 1, 4, 9]

# %%
E = func3(3, 4, 5, 10, 100)
print(E)
# Out:
# 717.106781187

# %%
F = func3(x=3, y=4, z=5, a=10, b=100)
print(F)
# Out:
# 717.106781187

# %%
G = func3(3, 4, 5, a=10, 100) # ERROR!
print(G)
# Out:
#   File "<ipython-input-45-7963f4c1b801>", line 1
#     G = func3(3, 4, 5, a=10, 100) # ERROR!
#                             ^
# SyntaxError: positional argument follows keyword argument

# %%
H = func3(3, 4, 5, b=10, a=100)
print(H)
# Out:
# 170.710678119

# %%
I = func3(z=5, x=3, y=4) # quite risky!
print(I)
# Out:
# 7.07106781187

# %%
# %%writefile ex1.py
def f1(x):
    return x**3
# Out:
# Overwriting ex1.py

# %%
# !cat ex1.py
# Out:
# def f1(x):
#     return x**3

# %%
import ex1
print(ex1.f1(4))
# Out:
# 64

# %%
from ex1 import f1
print(f1(3))
# Out:
# 27

# %%
import ex1 as tt
print(tt.f1(10))
# Out:
# 1000

# %%
# %run ex1
f1(8)

# %% [markdown]
# Help with TAB or ?

# %%
f1??

# %%
import numpy as np
a = np.array([1,2,3,4,5,6])
print(a)
# Out:
# [1 2 3 4 5 6]

# %%
print(a.mean(), a.max(), a.shape)
# Out:
# 3.5 6 (6,)

# %%
a.ndim
# Out:
# 1

# %% [markdown]
# mean and max are methods (functions) from the array object. shape is a attribute (variable).

# %%
print(np.ones_like(a))
# Out:
# [1 1 1 1 1 1]

# %%
print(a.reshape((3,2)))
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
print(a.reshape((3,-1)))
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
b = a.reshape((3,2))

# %%
print(a, b)
# Out:
# [1 2 3 4 5 6] [[1 2]
#  [3 4]
#  [5 6]]

# %%
b[1,1] = 100
print(b)
# Out:
# [[  1   2]
#  [  3 100]
#  [  5   6]]

# %%
print(a)
# Out:
# [  1   2   3 100   5   6]

# %%
a is b
# Out:
# False

# %%
b[1,1] is a[3]

# %%
b[1,1], a[3]
# Out:
# (100, 100)

# %%
a[3] = 200
print(b[1,1])
# Out:
# 200

# %%
c = a.reshape((3,2)).copy()
c[0,0] = -3
print(c)
print(a)
# Out:
# [[ -3   2]
#  [  3 200]
#  [  5   6]]
# [  1   2   3 200   5   6]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,101)
y = x**2
f, ax = plt.subplots()
ax.plot(x,y);

# %% [markdown]
# Check the matplotlib web site...

# %%
# the following is to have the nice style.
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#
#     h3{
#         margin-top:12px;
#         margin-bottom: 3px;
#         margin-left: -10px;
#         background-color: #fcf2f2;
#         border-color: #dFb5b4;
#         border-left: 5px solid #dfb5b4;
#         padding: 0.5em;
#         font-weight:normal;
#     }
#     div.text_cell_render h3 {
#      font-size: 14pt;
#      font-weight:normal;
#     }
#     div.text_cell_render h5 {
#         font-size: 12pt;
#         color: #4057A1;
#         font-style: italic;
#         font-weight:normal;
#         margin-bottom: .0em;
#         margin-top: 0.0em;
#         display: block;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# #    .prompt{
# #        display: None;
# #    }
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# # PLASMA DIAGNOSTICS

# %% [markdown]
# ## A catalogue of isoratios for plasma diagnostics

# %% [markdown]
# #### Consider the following ions: C$^{++}$, N$^{+}$, O$^{+}$, O$^{++}$, Ne$^{++}$, S$^{+}$, S$^{++}$, Cl$^{++}$, and Ar$^{3+}$.

# %% [markdown]
# ### For each of them, find line pairs that are susceptible to be easily observed (either in the UV, the optical or the IR domain) and to give temperature and/or density diagnostics. Note: some line pairs are strictly equivalent from the point of view of the plasma diagnostics. e.g. [O III] $\lambda$ 4363/[O III ] $\lambda$ 5007 and [O III] $\lambda$ 4363/[O III] $\lambda$ 4959. In that case, consider only the one involving the strongest line, i.e., in this case [O III ] $\lambda$ 4363/[O III] $\lambda$ 5007.

# %% [markdown]
# ##### We first import some useful libraries.

# %%
# %matplotlib inline
import numpy as np
import pyneb as pn
import matplotlib.pyplot as plt

# %%
Ar3 = pn.Atom('Ar',3)
f, ax = plt.subplots(figsize=(9,9))
Ar3.plotGrotrian(ax=ax)

# %% [markdown]
# ##### We ask PyNeb for all the ratio diagnostics that it manages.

# %%
for d in np.sort(list(pn.diags_dict)):
    print(d)
# Out:
# [ArIII] (7751+7136)/9m
# [ArIII] 5192/7136
# [ArIII] 5192/7300+
# [ArIII] 7136/9m
# [ArIII] 9.0m/21.8m
# [ArIV] 2860+/4720+
# [ArIV] 4740/4711
# [ArIV] 7230+/4720+
# [ArV] 4626/6600+
# [CIII] 1909/1907
# [ClIII] 5538/5518
# [ClIV] 5323/7531
# [ClIV] 5323/7700+
# [FeIII] 4659/4009
# [FeIII] 4659/4701
# [FeIII] 4659/4734
# [FeIII] 4701/4009
# [FeIII] 4701/4734
# [FeIII] 4734/4009
# [FeIII] 4881/4009
# [FeIII] 4881/4659
# [FeIII] 4881/4701
# [FeIII] 4881/4734
# [FeIII] 4881/4931
# [FeIII] 4881/5011
# [FeIII] 4925/4009
# [FeIII] 4925/4659
# [FeIII] 4925/4701
# [FeIII] 4925/4734
# [FeIII] 4925/4881
# [FeIII] 4925/4931
# [FeIII] 4925/5011
# [FeIII] 4931/4009
# [FeIII] 4931/4659
# [FeIII] 4931/4701
# [FeIII] 4931/4734
# [FeIII] 4987/4009
# [FeIII] 4987/4659
# [FeIII] 4987/4701
# [FeIII] 4987/4734
# [FeIII] 4987/4881
# [FeIII] 4987/4925
# [FeIII] 4987/4931
# [FeIII] 4987/5011
# [FeIII] 5011/4009
# [FeIII] 5011/4659
# [FeIII] 5011/4701
# [FeIII] 5011/4734
# [FeIII] 5011/4931
# [FeIII] 5270/4009
# [FeIII] 5270/4659
# [FeIII] 5270/4701
# [FeIII] 5270/4734
# [FeIII] 5270/4881
# [FeIII] 5270/4925
# [FeIII] 5270/4931
# [FeIII] 5270/4987
# [FeIII] 5270/5011
# [NIII] 1751+/57.4m
# [NII] 121m/20.5m
# [NII] 5755/6548
# [NII] 5755/6584
# [NII] 5755/6584+
# [NI] 5198/5200
# [NeIII] 15.6m/36.0m
# [NeIII] 3343/3930+
# [NeIII] 3344/3930+
# [NeIII] 3869/15.6m
# [NeIII] 3930+/15.6m
# [NeV] 14.3m/24.2m
# [NeV] 1575/3426
# [NeV] 2973/3370+
# [NeV] 3426/24.2m
# [NiIII] 6000/6401
# [NiIII] 6000/6682
# [NiIII] 6000/6797
# [NiIII] 6000/7125
# [NiIII] 6000/7890
# [NiIII] 6000/8500
# [NiIII] 6401/7125
# [NiIII] 6401/7890
# [NiIII] 6401/8500
# [NiIII] 6534/6401
# [NiIII] 6534/6682
# [NiIII] 6534/6797
# [NiIII] 6534/7125
# [NiIII] 6534/7890
# [NiIII] 6534/8500
# [NiIII] 6682/7125
# [NiIII] 6682/7890
# [NiIII] 6682/8500
# [NiIII] 6797/7125
# [NiIII] 6797/7890
# [NiIII] 6797/8500
# [NiIII] 6946/6401
# [NiIII] 6946/6682
# [NiIII] 6946/6797
# [NiIII] 6946/7125
# [NiIII] 6946/7890
# [NiIII] 6946/8500
# [OIII] 1664+/5007
# [OIII] 1666/4363
# [OIII] 1666/5007
# [OIII] 1666/5007+
# [OIII] 4363/5007
# [OIII] 4363/5007+
# [OIII] 5007/88m
# [OIII] 51m/88m
# [OII] 3726/3729
# [OII] 3727+/7325+
# [OII] 3727+/7325+b
# [OIV] 1400+/25.9m
# [OIV] 1401/1405
# [OI] 5577/6300
# [OI] 5577/6300+
# [OI] 5577/6302
# [OI] 63m/147m
# [SIII] 18.7m/33.5m
# [SIII] 6312/18.7m
# [SIII] 6312/9069
# [SIII] 6312/9200+
# [SIII] 9069/18.7m
# [SII] 4069/4076
# [SII] 4072+/6720+
# [SII] 6731/6716

# %%
print(pn.diags_dict['[OIII] 4363/5007+'])
# Out:
# ('O3', 'L(4363)/(L(5007)+L(4959))', 'RMS([E(5007)*L(5007)/(L(5007)+L(4959)), E(4959)*L(4959)/(L(5007)+L(4959)), E(4363)])')

# %% [markdown]
# ### For each of these pairs, construct an isoratio plot. Save the result.

# %%
# Select a maximum of 25 diagnostics
diags = ['[ArIII] 5192/7136', 
         '[ArIII] 9.0m/21.8m',
         '[ArIV] 4740/4711',
         '[CIII] 1909/1907',
         '[ClIII] 5538/5518',
         '[NII] 121m/20.5m',
         '[NII] 5755/6584',
         '[NeIII] 15.6m/36.0m',
         '[NeIII] 3343/3930+',
         '[NeV] 14.3m/24.2m',
         '[NeV] 2973/3370+',
         '[OI] 5577/6300+',
         '[OI] 63m/147m',
         '[OII] 3726/3729',
         '[OII] 3727+/7325+',
         '[OIII] 1664+/5007',
         '[OIII] 5007/88m', 
         '[OIII] 4363/5007',
         '[OIV] 1400+/25.9m',
         '[OIV] 1401/1405',
         '[SII] 4072+/6720+',
         '[SII] 4069/4076', 
         '[SII] 6731/6716',
         '[SIII] 6312/9069',
         '[SIII] 18.7m/33.5m'
         ] 
# Build the 25 subplots
f, axes = plt.subplots(5, 5, figsize=(20,20))
# loop on the diagnostics
for i, d in enumerate(diags):
    # extract from the diagnostic dictionnary 
    # the expression to be evaluated
    to_eval = pn.diags_dict[d][1]
    atom = pn.diags_dict[d][0]
    # split e.g. obtain 'O', 3 from 'O3'
    elem, spec = pn.utils.misc.parseAtom(atom)
    # instantiate the EmisGrid object for the given ion 
    EG = pn.EmisGrid(elem, spec)
    # select the axis in which to plot
    ax = axes.ravel()[i]
    # make the plot
    EG.plotContours(to_eval = to_eval, ax=ax)
# Make the plot nicer
f.tight_layout()
# Save the result in a pdf file
f.savefig('Diagnostics.pdf')

# %% [markdown]
# ### ??? Looking at these plots, for each of them find the temperature/density domain where they are useful for plasma diagnostics.

# %% [markdown]
# ##### We plot the Grotrian diagram to see where the lines are coming from.

# %%
f, ax = plt.subplots(figsize=(12,8))
O2 = pn.Atom('O',2)
O2.plotGrotrian(ax=ax)

# %% [markdown]
# ##### From the critical densities, we can have an idea of the density range.

# %%
print(O2.getCritDensity(tem=1e4))
# Out:
# [  0.00000000e+00   1.30322285e+03   4.05631759e+03   5.39592182e+06
#    3.78619444e+06]

# %% [markdown]
# ##### We can use a method in Atom to obtain the minimum and maximum densities between which the diagnostic as a meaning.

# %%
help(O2.getDensityRange)
# Out:
# Help on method getDensityRange in module pyneb.core.pynebcore:
#
# getDensityRange(lev_i1=-1, lev_i2=-1, lev_j1=-1, lev_j2=-1, wave1=-1, wave2=-1, to_eval=None, tol=0.1, tem=10000.0) method of pyneb.core.pynebcore.Atom instance
#     Return the range of density where a given line ratio is between 10% and 90% of the low and high density limits

# %%
print(O2.getDensityRange(to_eval='L(3726)/L(3729)'))
# Out:
# [   312.06079187  23239.70857753]

# %% [markdown]
# ### Do a similar plot for the recombination lines

# %%
o2 = pn.RecAtom('O',2)
tem = np.logspace(2, 4.5, 100)
den = np.logspace(2, 5, 100) 
den2D, tem2D = np.meshgrid(den, tem)

i1 = o2.getEmissivity(tem, den, label='4649.13')
i2 = o2.getEmissivity(tem, den, label='4089.29')
i3 = o2.getEmissivity(tem, den, label='4661.63')

f, ax = plt.subplots(figsize=(9, 9))
CS = ax.contour(np.log10(den2D), np.log10(tem2D), i1/i2, levels=[2.26, 2.27, 2.28, 2.29, 2.3, 2.31, 2.32, 2.5, 3, 3.5, 4, 4.5, 5, 5.5])
ax.clabel(CS, CS.levels, inline=True, fontsize=12, colors='black')

CS = ax.contour(np.log10(den2D), np.log10(tem2D), i1/i3, linestyles='--')
ax.clabel(CS, CS.levels, inline=True, fontsize=12, colors='black')

ax.set_xlabel('log(Ne)')
ax.set_ylabel('log(T)');

# %%
# the following is to have the nice style.
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
